# %%
import time
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import matplotlib.pyplot as plt


mnist = input_data.read_data_sets("/tmp/data/", one_hot = True)
# Out:
# C:\Users\wtais\Anaconda3\envs\hackthewind\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
class VAE():
    
    def __init__(self,beta=1,latent_dim=20,batch_size=1000,learning_rate=1e-4,network_type='fully_connected'):
        self.beta=beta
        self.network_type = network_type
        self.latent_dim = latent_dim
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.x = tf.placeholder('float', [None, 784], name='x')
        self._build_network()
        self._vae_loss_and_optimizer()
        
        # Initializing the tensorflow variables
        init = tf.global_variables_initializer()

        # Launch the session
        self.sess = tf.InteractiveSession()
        self.sess.run(init)
        
    def _build_network(self):
        if self.network_type is 'fully_connected':
            self._initialize_weights_fc()
            self._encoder_fc(self.x)
            self._sample_z()
            self._decoder_fc()
  
    def _initialize_weights_fc(self):
        encoder_hl1_nodes = 512
        encoder_out_nodes = 512
        decoder_hl1_nodes = 512
        decoder_out_nodes = 512
        initializer = tf.contrib.layers.xavier_initializer()
        
        self.encoder_input = {'weights':tf.Variable(initializer([784, encoder_hl1_nodes]), name='encoder_input_w'),
                          'biases':tf.Variable(initializer([encoder_hl1_nodes]), name='encoder_input_b')}

        self.encoder_hidden_1 = {'weights':tf.Variable(initializer([encoder_hl1_nodes, encoder_out_nodes]), name='encoder_h1_w'),
                          'biases':tf.Variable(initializer([encoder_out_nodes]), name='encoder_h1_b')}

        self.encoder_output_mu = {'weights':tf.Variable(initializer([encoder_out_nodes, self.latent_dim]), name='encoder_out_mu_w'),
                        'biases':tf.Variable(initializer([self.latent_dim]), name='encoder_out_mu_b')}

        self.encoder_output_log_sigma = {'weights':tf.Variable(initializer([encoder_out_nodes, self.latent_dim]), name='encoder_out_log_sigma_w'),
                        'biases':tf.Variable(initializer([self.latent_dim]), name='encoder_out_log_sigma_b')}
        
        self.decoder_input = {'weights':tf.Variable(initializer([self.latent_dim, decoder_hl1_nodes]), name='decoder_input_w'),
                          'biases':tf.Variable(initializer([encoder_hl1_nodes]), name='decoder_input_b')}

        self.decoder_hidden_1 = {'weights':tf.Variable(initializer([decoder_hl1_nodes, decoder_out_nodes]), name='decoder_h1_w'),
                          'biases':tf.Variable(initializer([encoder_out_nodes]), name='decoder_h1_b')}

        self.decoder_output = {'weights':tf.Variable(initializer([decoder_out_nodes, 784]), name='decoder_output_w'),
                        'biases':tf.Variable(initializer([784]), name='decoder_output_b')}
        
    def _encoder_fc(self, data):
        l1 = tf.add(tf.matmul(data,self.encoder_input['weights']), self.encoder_input['biases'])
        l1 = tf.nn.relu(l1)
        l1 = tf.layers.batch_normalization(l1)

        self.z_mu = tf.add(tf.matmul(l1,self.encoder_output_mu['weights']), self.encoder_output_mu['biases'])
        self.z_log_sigma = tf.add(tf.matmul(l1,self.encoder_output_log_sigma['weights']), self.encoder_output_log_sigma['biases'])
        
    def _decoder_fc(self):
        l1 = tf.add(tf.matmul(self.z,self.decoder_input['weights']), self.decoder_input['biases'])
        l1 = tf.nn.relu(l1)
        l1 = tf.layers.batch_normalization(l1)

        out = tf.add(tf.matmul(l1,self.decoder_output['weights']), self.decoder_output['biases'])
        self.x_reconstruction_mean = tf.nn.sigmoid(out)

    def _sample_z(self):
        # sample z using reparameterization trick
        epsilon = tf.random_normal(shape=[self.batch_size, self.latent_dim],mean=0.0, stddev=1.0, name='epsilon', dtype='float32')
        self.z = tf.add(self.z_mu,tf.multiply(epsilon, tf.exp(0.5 * self.z_log_sigma)), name='z')
        
    def _vae_loss_and_optimizer(self):
        self.recon = tf.reduce_sum(tf.keras.backend.binary_crossentropy(self.x, self.x_reconstruction_mean))
        # KL divergence between q(z|x) and p(z)
        self.kl = 0.5 * tf.reduce_sum(tf.exp(self.z_log_sigma) + tf.square(self.z_mu) - 1 - self.z_log_sigma, 1)

        self.loss = tf.reduce_mean(self.recon + self.beta*self.kl, name='loss')
        self.optimizer = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss)

    def fit(self, x_batch):
        return self.sess.run([self.optimizer, self.loss], feed_dict={self.x: x_batch})
        
    def reconstruct_X(self, x_true):
        return self.sess.run(self.x_reconstruction_mean, feed_dict={self.x: x_true})
    
    def generate(self, z_mu=None):
        if z_mu is None:
            z_mu = np.random.normal(size=[self.batch_size, self.latent_dim])
        # Note: This maps to mean of distribution, we could alternatively
        # sample from Gaussian distribution
        return self.sess.run(self.x_reconstruction_mean, 
                             feed_dict={self.z: z_mu})

# %% [markdown]
# #### Instantiate VAE and Saver

# %%
vae = VAE(beta=1,batch_size=1000,learning_rate=1e-4,network_type='fully_connected',latent_dim=2)
saver = tf.train.Saver()

# %% [markdown]
# #### Training

# %%
def draw_digits(digits, n_rows):
    n = n_rows**2
    n_cols = n_rows
    for i in range(0, n):
        plt.figsize=(12,12)
        plt.subplot(n_rows, n_cols, i+1)
        img = digits[int(n_rows*i)].reshape(28,28)
        plt.imshow(img, cmap='gray', interpolation='none')
        plt.axis('off')
        plt.subplots_adjust(hspace=0.0, wspace=0.0)

# %%
vae.loss
# Out:
# <tf.Tensor 'loss_1:0' shape=() dtype=float32>

# %%
list_of_latent_spaces = []
hm_epochs = 1000

# for plotting latent space every 50 epochs
MM = vae.batch_size
grid_max = 100.0
z_test1 = np.linspace(grid_max,-grid_max,MM)
z_test2 = np.linspace(grid_max,-grid_max,MM)
zz = np.array([z_test1,z_test2])
zz = np.transpose(zz)

for epoch in range(hm_epochs):
    epoch_loss = 0
    for _ in range(int(mnist.train.num_examples/vae.batch_size)):
        epoch_x, _ = mnist.train.next_batch(vae.batch_size)
        _, c = vae.fit(np.rint(epoch_x).astype(np.float32))
        epoch_loss += c
    
    if epoch % 10 is 0:
        print('Epoch', epoch+1, '/',hm_epochs,'; loss:',epoch_loss,end=';')
        print('Reconstruction loss : ', vae.recon, end=';')
        print('KL loss', vae.kl)

    if epoch % 50 is 0:
        x_gen = vae.generate(zz)
        list_of_latent_spaces.append(x_gen)

        plt.close()
        fig = plt.figure(figsize=(5,5))
        draw_digits(x_gen,10)
        plt.show()
# Out:
# Epoch 1 / 1000 ; loss: 12399794.078125;Reconstruction loss :  Tensor("Sum_1:0", shape=(), dtype=float32);KL loss Tensor("mul_4:0", shape=(?,), dtype=float32)
# Epoch 11 / 1000 ; loss: 10926124.9375;Reconstruction loss :  Tensor("Sum_1:0", shape=(), dtype=float32);KL loss Tensor("mul_4:0", shape=(?,), dtype=float32)
# Epoch 21 / 1000 ; loss: 10158774.4375;Reconstruction loss :  Tensor("Sum_1:0", shape=(), dtype=float32);KL loss Tensor("mul_4:0", shape=(?,), dtype=float32)
# Epoch 31 / 1000 ; loss: 9820411.890625;Reconstruction loss :  Tensor("Sum_1:0", shape=(), dtype=float32);KL loss Tensor("mul_4:0", shape=(?,), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c7dde491d18c> in <module>()
#      15         epoch_x, _ = mnist.train.next_batch(vae.batch_size)
#      16 #         _, c = vae.fit(np.rint(epoch_x).astype(np.float32))
# ---> 17         _, c = vae.fit(epoch_x)
#      18         epoch_loss += c
#      19
#
# <ipython-input-7-a7622a28c24f> in fit(self, x_batch)
#      83
#      84     def fit(self, x_batch):
# ---> 85         return self.sess.run([self.optimizer, self.loss], feed_dict={self.x: x_batch})
#      86
#      87     def reconstruct_X(self, x_true):
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
len(mnist.train.next_batch(vae.batch_size))
# Out:
# 2

# %%
np.rint(mnist.train.next_batch(vae.batch_size))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d4e98b18d3a1> in <module>()
# ----> 1 np.rint(mnist.train.next_batch(vae.batch_size))
#
# ValueError: could not broadcast input array from shape (1000,784) into shape (1000)

# %% [markdown]
# #### Only use this section if saving model

# %%
timestr = time.strftime("%Y%m%d-%H%M%S")
filename = 'saved_models/vae-fc-'
saved_filename = filename+timestr
saver.save(vae.sess,filename+timestr)
# Out:
# 'saved_models/vae-fc-20181022-231550'

# %% [markdown]
# #### Restoring model weights

# %%
saver.restore(vae.sess, 'saved_models/vae-fc-20181021-230516')
# Out:
# INFO:tensorflow:Restoring parameters from saved_models/vae-fc-20181021-230516

# %% [markdown]
# #### Visualise latent space

# %%
MM = vae.batch_size
grid_max = 1.0
z_test1 = np.linspace(grid_max,-grid_max,MM)
z_test2 = np.linspace(grid_max,-grid_max,MM)
zz = np.array([np.zeros([vae.batch_size,]),z_test2])
zz = np.transpose(zz)

# %%
x_gen = vae.generate(zz)

# %%
list_of_latent_spaces[-1]
# Out:
# array([[-2.2325623e-03,  2.3086490e-03, -3.5904348e-05, ...,
#          2.7332641e-04, -5.2299351e-04,  2.5754813e-03],
#        [-2.2235545e-03,  2.3053410e-03, -3.9307401e-05, ...,
#          2.7263351e-04, -5.1542372e-04,  2.5741030e-03],
#        [-2.2147768e-03,  2.3020832e-03, -4.2514876e-05, ...,
#          2.7222000e-04, -5.0767884e-04,  2.5728643e-03],
#        ...,
#        [ 4.3266406e-04, -7.9169590e-04,  1.3357587e-04, ...,
#         -1.1308435e-03, -1.7642118e-03, -1.3611866e-03],
#        [ 4.3457141e-04, -7.9307705e-04,  1.3113394e-04, ...,
#         -1.1298433e-03, -1.7652214e-03, -1.3630977e-03],
#        [ 4.3648761e-04, -7.9446938e-04,  1.2868643e-04, ...,
#         -1.1288580e-03, -1.7662272e-03, -1.3650116e-03]], dtype=float32)

# %%
# %matplotlib inline
for picture in list_of_latent_spaces:
    fig = plt.figure(figsize=(5,5))
    draw_digits(picture,10)
    
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-182-5fcdbc06e998> in <module>()
#       2 for picture in list_of_latent_spaces:
#       3     fig = plt.figure(figsize=(5,5))
# ----> 4     draw_digits(picture,10)
#       5
#       6     plt.show()
#
# <ipython-input-162-fc3444d943fc> in draw_digits(digits, n_rows)
#       8         plt.imshow(img, cmap='gray', interpolation='none')
#       9         plt.axis('off')
# ---> 10         plt.subplots_adjust(hspace=0.0, wspace=0.0)
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\matplotlib\pyplot.py in subplots_adjust(left, bottom, right, top, wspace, hspace)
#    1332     """
#    1333     fig = gcf()
# -> 1334     fig.subplots_adjust(left, bottom, right, top, wspace, hspace)
#    1335
#    1336
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\matplotlib\figure.py in subplots_adjust(self, left, bottom, right, top, wspace, hspace)
#    2160                     ax.set_position(ax._sharey.figbox)
#    2161             else:
# -> 2162                 ax.update_params()
#    2163                 ax.set_position(ax.figbox)
#    2164         self.stale = True
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\matplotlib\axes\_subplots.py in update_params(self)
#     126         self.figbox, self.rowNum, self.colNum, self.numRows, self.numCols = \
#     127             self.get_subplotspec().get_position(self.figure,
# --> 128                                                 return_all=True)
#     129
#     130     def is_first_col(self):
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\matplotlib\gridspec.py in get_position(self, figure, return_all)
#     489         fig_top = fig_tops[rows].max()
#     490         fig_left = fig_lefts[cols].min()
# --> 491         fig_right = fig_rights[cols].max()
#     492         figbox = Bbox.from_extents(fig_left, fig_bottom, fig_right, fig_top)
#     493
#
# ~\Anaconda3\envs\hackthewind\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
fig, axs = plt.subplots(1,1, figsize=(15, 6))
n = 42
j = 0

plt.imshow(x_gen[n,:].reshape([28,28]),cmap='gray',interpolation='none')
plt.show()

# %%
vae.z
# Out:
# <tf.Tensor 'z_1:0' shape=(30000, 2) dtype=float32>

# %%
fig, axs = plt.subplots(1,1, figsize=(15, 6))
n = 42
j = 0

plt.imshow(x_gen[n,:].reshape([28,28]),cmap='gray',interpolation='none')
plt.colorbar()
plt.show()

# %% [markdown]
# #### Visualise data reconstruction

# %%
test_epoch, _ = mnist.train.next_batch(vae.batch_size)
x_tst = vae.reconstruct_X(test_epoch)

# %%
fig, axs = plt.subplots(2,5, figsize=(15, 6))
axs = axs.ravel()
n = 100
j = 0

for i in range(n,n+5):
    axs[j].imshow(x_tst[i,:].reshape([28,28]),cmap='gray')
    axs[j+5].imshow(test_epoch[i,:].reshape([28,28]),cmap='gray')
    j += 1
    
plt.show()

# %%
print(x_tst[0,:][0:5],x_tst[1,:][0:5])

# %%
x_tst[0,:]/np.max(x_tst[0,:])
# Out:
# array([-3.16540480e-01, -1.63760930e-01, -4.60094064e-02, -2.43581071e-01,
#        -2.52675086e-01, -2.29571804e-01, -2.66560018e-01, -1.71689287e-01,
#        -1.62934884e-01, -3.30409527e-01, -1.81725174e-01, -3.16497535e-01,
#        -1.93883657e-01, -2.29616582e-01, -1.07660875e-01, -1.82175443e-01,
#        -2.56732702e-01, -2.10156471e-01, -2.32163385e-01, -1.48748323e-01,
#        -2.38691673e-01, -1.54717952e-01, -2.49761462e-01, -3.09027046e-01,
#        -1.32282898e-01, -2.14519337e-01, -1.56842813e-01, -1.61891282e-01,
#        -1.64044410e-01, -1.99564189e-01, -3.51291090e-01, -9.99744833e-02,
#        -1.22890458e-01, -3.35551202e-01, -2.72681832e-01, -8.36041123e-02,
